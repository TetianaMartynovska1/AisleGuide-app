# %% [markdown]
# <a href="https://colab.research.google.com/github/TetianaMartynovska1/AisleGuide-app/blob/main/lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(cluster)
library(factoextra)
votes.repub |> scale() |>
                hcut(k = 5, hc_func = "agnes",
                     hc_method = "complete",
                     hc_metric = "manhattan") |>
                fviz_dend()
# Out:
# Loading required package: ggplot2
#
# Welcome to factoextra!
#
# Want to learn more? See two factoextra-related books at https://www.datanovia.com/en/product/practical-guide-to-principal-component-methods-in-r/
# plot without title

# %%
install.packages("factoextra")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
votes.repub |> scale() |>
                hcut(k = 5, hc_func = "agnes",
                     hc_method = "average",
                     hc_metric = "euclidean") |>
                fviz_dend() -> dendro1
votes.repub |> scale() |>
                hcut(k = 5, hc_func = "agnes",
                     hc_method = "complete",
                     hc_metric = "manhattan") |>
                fviz_dend() -> dendro2

library(patchwork)
dendro1 / dendro2
# Out:
# plot without title

# %%
install.packages("patchwork")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
votes.repub |> scale() |>
                hcut(k = 5, hc_func = "agnes",
                     hc_method = "average",
                     hc_metric = "euclidean") -> clust1
votes.repub |> scale() |>
                hcut(k = 5, hc_func = "agnes",
                     hc_method = "complete",
                     hc_metric = "manhattan") -> clust2

library(dendextend)
tanglegram(as.dendrogram(clust1),
           as.dendrogram(clust2),
           k_labels = 5,
           k_branches = 5)
# Out:
# ---------------------
# Welcome to dendextend version 1.19.1
# Type citation('dendextend') for how to cite the package.
#
# Type browseVignettes(package = 'dendextend') for the package vignette.
# The github page is: https://github.com/talgalili/dendextend/
#
# Suggestions and bug-reports can be submitted at: https://github.com/talgalili/dendextend/issues
# You may ask questions at stackoverflow, use the r and dendextend tags:
# 	 https://stackoverflow.com/questions/tagged/dendextend
#
# 	To suppress this message use:  suppressPackageStartupMessages(library(dendextend))
# ---------------------
#
#
#
# Attaching package: ‘dendextend’
#
#
# The following object is masked from ‘package:stats’:
#
#     cutree
#
#
# Loading required namespace: colorspace
# Plot with title “”

# %%
library(cluster)
USArrests |> scale() |>
                agnes() |>
                plot(which = 2)
# Out:
# Plot with title “Dendrogram of  agnes(x = scale(USArrests))”

# %%
library(cluster)
USArrests |> as.matrix() |> heatmap(scale = "col")
# Out:
# plot without title

# %%
library(cluster)
?chorSub

# Scatterplot matrix:
library(GGally)
ggpairs(chorSub)
# Out:
# plot without title

# %%
install.packages("GGally")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘ggstats’

# %%
library(factoextra)
chorSub |> scale() |>
                fviz_nbclust(pam, method = "wss")
chorSub |> scale() |>
                fviz_nbclust(pam, method = "silhouette")
chorSub |> scale() |>
                fviz_nbclust(pam, method = "gap")
# Out:
# plot without title
# plot without title
# plot without title

# %%
# k = 3:
chorSub |> scale() |>
                pam(k = 3) -> kola_cluster
fviz_cluster(kola_cluster, geom = "point")

# k = 7:
chorSub |> scale() |>
                pam(k = 7) -> kola_cluster
fviz_cluster(kola_cluster, geom = "point")
# Out:
# plot without title
# plot without title

# %%
library(factoextra)
USArrests |> scale() |>
                fviz_nbclust(fanny, method = "wss")
USArrests |> scale() |>
                fviz_nbclust(fanny, method = "silhouette")
# Out:
# plot without title
# plot without title

# %%
library(cluster)
USArrests |> scale() |>
                fanny(k = 2) -> USAclusters

# Show memberships:
USAclusters$membership
# Out:
#                [,1]      [,2]
# Alabama        0.6641977 0.3358023
# Alaska         0.6098062 0.3901938
# Arizona        0.6862278 0.3137722
# Arkansas       0.4882102 0.5117898
# California     0.6447279 0.3552721
# Colorado       0.6461462 0.3538538
# Connecticut    0.3233259 0.6766741
# Delaware       0.5034392 0.4965608
# Florida        0.6820417 0.3179583
# Georgia        0.6547524 0.3452476
# Hawaii         0.3930926 0.6069074
# Idaho          0.2677451 0.7322549
# Illinois       0.6916199 0.3083801
# Indiana        0.3451651 0.6548349
# Iowa           0.2656496 0.7343504
# Kansas         0.2743898 0.7256102
# Kentucky       0.3919749 0.6080251
# Louisiana      0.6898500 0.3101500
# Maine          0.2907691 0.7092309
# Maryland       0.7262297 0.2737703
# Massachusetts  0.4190098 0.5809902
# Michigan       0.7290950 0.2709050
# Minnesota      0.2567805 0.7432195
# Mississippi    0.5897896 0.4102104
# Missouri       0.6404459 0.3595541
# Montana        0.2827456 0.7172544
# Nebraska       0.2339900 0.7660100
# Nevada         0.6518656 0.3481344
# New Hampshire  0.2742191 0.7257809
# New Jersey     0.5077570 0.4922430
# New Mexico     0.7380909 0.2619091
# New York       0.6944489 0.3055511
# North Carolina 0.5894751 0.4105249
# North Dakota   0.3308097 0.6691903
# Ohio           0.4185939 0.5814061
# Oklahoma       0.3780939 0.6219061
# Oregon         0.4927356 0.5072644
# Pennsylvania   0.3031181 0.6968819
# Rhode Island   0.4236501 0.5763499
# South Carolina 0.6339733 0.3660267
# South Dakota   0.3000782 0.6999218
# Tennessee      0.6633771 0.3366229
# Texas          0.6920383 0.3079617
# Utah           0.4020941 0.5979059
# Vermont        0.3661574 0.6338426
# Virginia       0.4557075 0.5442925
# Washington     0.4372252 0.5627748
# West Virginia  0.3477456 0.6522544
# Wisconsin      0.2750357 0.7249643
# Wyoming        0.3405825 0.6594175

# %%
library(cluster)
library(mclust)
kola_cluster <- Mclust(scale(chorSub))
summary(kola_cluster)

# Plot results with ellipsoids:
library(factoextra)
fviz_cluster(kola_cluster, geom = "point", ellipse.type = "norm")
# Out:
# Package 'mclust' version 6.1.2
# Type 'citation("mclust")' for citing this R package in publications.
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust EVE (ellipsoidal, equal volume and orientation) model with 3 components:
#
#  log-likelihood  n  df       BIC       ICL
#       -412.7876 61 105 -1257.217 -1257.306
#
# Clustering table:
#  1  2  3
# 31 14 16
# plot without title

# %%
install.packages("mclust")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
